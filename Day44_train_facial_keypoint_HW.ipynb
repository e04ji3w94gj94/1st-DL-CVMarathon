# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'data/training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /home/faifai/anaconda3/envs/deeplearning-gpu/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/faifai/anaconda3/envs/deeplearning-gpu/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3138: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /home/faifai/anaconda3/envs/deeplearning-gpu/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 0.0070 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00206, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00206 to 0.00185, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00185 to 0.00185, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve
# Epoch 5/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00185 to 0.00182, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00182 to 0.00182, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 9.8948e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00182 to 0.00170, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 8.3358e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00170 to 0.00164, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 7.2745e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00164 to 0.00136, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 6.1937e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00136 to 0.00125, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 5.6620e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00125 to 0.00117, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 5.2389e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00117 to 0.00114, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 4.9320e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00114 to 0.00108, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 4.5152e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve
# Epoch 15/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 4.3023e-04 - val_loss: 9.7433e-04
#
# Epoch 00015: val_loss improved from 0.00108 to 0.00097, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 3.9680e-04 - val_loss: 9.2941e-04
#
# Epoch 00016: val_loss improved from 0.00097 to 0.00093, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 3.8581e-04 - val_loss: 9.4267e-04
#
# Epoch 00017: val_loss did not improve
# Epoch 18/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 3.5481e-04 - val_loss: 8.9193e-04
#
# Epoch 00018: val_loss improved from 0.00093 to 0.00089, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 3.5248e-04 - val_loss: 9.2111e-04
#
# Epoch 00019: val_loss did not improve
# Epoch 20/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 3.3345e-04 - val_loss: 8.6360e-04
#
# Epoch 00020: val_loss improved from 0.00089 to 0.00086, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 3.2212e-04 - val_loss: 8.4152e-04
#
# Epoch 00021: val_loss improved from 0.00086 to 0.00084, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 3.0919e-04 - val_loss: 8.4635e-04
#
# Epoch 00022: val_loss did not improve
# Epoch 23/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 2.9533e-04 - val_loss: 8.7647e-04
#
# Epoch 00023: val_loss did not improve
# Epoch 24/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 2.9128e-04 - val_loss: 8.4039e-04
#
# Epoch 00024: val_loss improved from 0.00084 to 0.00084, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 2.8349e-04 - val_loss: 8.1941e-04
#
# Epoch 00025: val_loss improved from 0.00084 to 0.00082, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 2.6757e-04 - val_loss: 8.3163e-04
#
# Epoch 00026: val_loss did not improve
# Epoch 27/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 2.6712e-04 - val_loss: 8.0482e-04
#
# Epoch 00027: val_loss improved from 0.00082 to 0.00080, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 2.6134e-04 - val_loss: 7.9687e-04
#
# Epoch 00028: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 2.5879e-04 - val_loss: 7.8670e-04
#
# Epoch 00029: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 2.4886e-04 - val_loss: 7.8950e-04
#
# Epoch 00030: val_loss did not improve
# Epoch 31/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 2.3896e-04 - val_loss: 7.7668e-04
#
# Epoch 00031: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 2.3126e-04 - val_loss: 7.7318e-04
#
# Epoch 00032: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 2.3844e-04 - val_loss: 7.6244e-04
#
# Epoch 00033: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 2.3226e-04 - val_loss: 7.7519e-04
#
# Epoch 00034: val_loss did not improve
# Epoch 35/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 2.2418e-04 - val_loss: 7.9705e-04
#
# Epoch 00035: val_loss did not improve
# Epoch 36/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 2.1647e-04 - val_loss: 7.6076e-04
#
# Epoch 00036: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 2.1994e-04 - val_loss: 7.8085e-04
#
# Epoch 00037: val_loss did not improve
# Epoch 38/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 2.1625e-04 - val_loss: 7.7847e-04
#
# Epoch 00038: val_loss did not improve
# Epoch 39/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 2.1145e-04 - val_loss: 7.7302e-04
#
# Epoch 00039: val_loss did not improve
# Epoch 40/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 2.0938e-04 - val_loss: 7.9255e-04
#
# Epoch 00040: val_loss did not improve
# Epoch 41/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 2.0475e-04 - val_loss: 7.4599e-04
#
# Epoch 00041: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 42/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.9787e-04 - val_loss: 7.4152e-04
#
# Epoch 00042: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 43/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.9966e-04 - val_loss: 7.5387e-04
#
# Epoch 00043: val_loss did not improve
# Epoch 44/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.9720e-04 - val_loss: 7.4519e-04
#
# Epoch 00044: val_loss did not improve
# Epoch 45/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.9146e-04 - val_loss: 7.4989e-04
#
# Epoch 00045: val_loss did not improve
# Epoch 46/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.8751e-04 - val_loss: 7.4500e-04
#
# Epoch 00046: val_loss did not improve
# Epoch 47/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.8732e-04 - val_loss: 7.3212e-04
#
# Epoch 00047: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 48/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.8332e-04 - val_loss: 7.5916e-04
#
# Epoch 00048: val_loss did not improve
# Epoch 49/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.8222e-04 - val_loss: 7.5134e-04
#
# Epoch 00049: val_loss did not improve
# Epoch 50/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.8105e-04 - val_loss: 7.2974e-04
#
# Epoch 00050: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.7910e-04 - val_loss: 7.5678e-04
#
# Epoch 00051: val_loss did not improve
# Epoch 52/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.7394e-04 - val_loss: 7.2330e-04
#
# Epoch 00052: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.6914e-04 - val_loss: 7.2248e-04
#
# Epoch 00053: val_loss improved from 0.00072 to 0.00072, saving model to best_weights.h5
# Epoch 54/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.7056e-04 - val_loss: 7.3164e-04
#
# Epoch 00054: val_loss did not improve
# Epoch 55/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.6403e-04 - val_loss: 7.3824e-04
#
# Epoch 00055: val_loss did not improve
# Epoch 56/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.6308e-04 - val_loss: 7.4403e-04
#
# Epoch 00056: val_loss did not improve
# Epoch 57/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.6073e-04 - val_loss: 7.5218e-04
#
# Epoch 00057: val_loss did not improve
# Epoch 58/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.6130e-04 - val_loss: 7.2126e-04
#
# Epoch 00058: val_loss improved from 0.00072 to 0.00072, saving model to best_weights.h5
# Epoch 59/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.5956e-04 - val_loss: 7.4998e-04
#
# Epoch 00059: val_loss did not improve
# Epoch 60/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 1.5648e-04 - val_loss: 7.3271e-04
#
# Epoch 00060: val_loss did not improve
# Epoch 61/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.5624e-04 - val_loss: 7.3777e-04
#
# Epoch 00061: val_loss did not improve
# Epoch 62/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 1.6287e-04 - val_loss: 7.2915e-04
#
# Epoch 00062: val_loss did not improve
# Epoch 63/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 1.5620e-04 - val_loss: 7.3695e-04
#
# Epoch 00063: val_loss did not improve
# Epoch 64/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.5025e-04 - val_loss: 7.6385e-04
#
# Epoch 00064: val_loss did not improve
# Epoch 65/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.5261e-04 - val_loss: 7.3498e-04
#
# Epoch 00065: val_loss did not improve
# Epoch 66/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.4778e-04 - val_loss: 7.2813e-04
#
# Epoch 00066: val_loss did not improve
# Epoch 67/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.5015e-04 - val_loss: 7.5404e-04
#
# Epoch 00067: val_loss did not improve
# Epoch 68/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.4591e-04 - val_loss: 6.9776e-04
#
# Epoch 00068: val_loss improved from 0.00072 to 0.00070, saving model to best_weights.h5
# Epoch 69/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.4285e-04 - val_loss: 7.5141e-04
#
# Epoch 00069: val_loss did not improve
# Epoch 70/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.4389e-04 - val_loss: 7.2659e-04
#
# Epoch 00070: val_loss did not improve
# Epoch 71/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.3893e-04 - val_loss: 7.3467e-04
#
# Epoch 00071: val_loss did not improve
# Epoch 72/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.3961e-04 - val_loss: 7.0081e-04
#
# Epoch 00072: val_loss did not improve
# Epoch 73/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.3877e-04 - val_loss: 7.7117e-04
#
# Epoch 00073: val_loss did not improve
# Epoch 74/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.3985e-04 - val_loss: 7.2946e-04
#
# Epoch 00074: val_loss did not improve
# Epoch 75/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.4078e-04 - val_loss: 7.2471e-04
#
# Epoch 00075: val_loss did not improve
# Epoch 76/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.3734e-04 - val_loss: 7.6576e-04
#
# Epoch 00076: val_loss did not improve
# Epoch 77/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.3441e-04 - val_loss: 7.0117e-04
#
# Epoch 00077: val_loss did not improve
# Epoch 78/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.3898e-04 - val_loss: 7.2409e-04
#
# Epoch 00078: val_loss did not improve
# Epoch 79/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.3266e-04 - val_loss: 7.4078e-04
#
# Epoch 00079: val_loss did not improve
# Epoch 80/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.3171e-04 - val_loss: 7.1420e-04
#
# Epoch 00080: val_loss did not improve
# Epoch 81/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.3124e-04 - val_loss: 7.2572e-04
#
# Epoch 00081: val_loss did not improve
# Epoch 82/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.2793e-04 - val_loss: 7.1276e-04
#
# Epoch 00082: val_loss did not improve
# Epoch 83/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.2875e-04 - val_loss: 7.1286e-04
#
# Epoch 00083: val_loss did not improve
# Epoch 84/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.2576e-04 - val_loss: 7.2863e-04
#
# Epoch 00084: val_loss did not improve
# Epoch 85/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.2655e-04 - val_loss: 7.1962e-04
#
# Epoch 00085: val_loss did not improve
# Epoch 86/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.2631e-04 - val_loss: 7.1759e-04
#
# Epoch 00086: val_loss did not improve
# Epoch 87/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.2273e-04 - val_loss: 7.0633e-04
#
# Epoch 00087: val_loss did not improve
# Epoch 88/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.2369e-04 - val_loss: 7.0694e-04
#
# Epoch 00088: val_loss did not improve
# Epoch 89/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.2076e-04 - val_loss: 7.2440e-04
#
# Epoch 00089: val_loss did not improve
# Epoch 90/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.2175e-04 - val_loss: 7.2202e-04
#
# Epoch 00090: val_loss did not improve
# Epoch 91/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.1995e-04 - val_loss: 7.2709e-04
#
# Epoch 00091: val_loss did not improve
# Epoch 92/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 1.2372e-04 - val_loss: 7.1831e-04
#
# Epoch 00092: val_loss did not improve
# Epoch 93/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.2087e-04 - val_loss: 7.1078e-04
#
# Epoch 00093: val_loss did not improve
# Epoch 94/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.2025e-04 - val_loss: 7.6205e-04
#
# Epoch 00094: val_loss did not improve
# Epoch 95/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.1883e-04 - val_loss: 7.2376e-04
# Epoch 00095: val_loss did not improve
# Epoch 96/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.1923e-04 - val_loss: 7.4952e-04
#
# Epoch 00096: val_loss did not improve
# Epoch 97/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 1.1335e-04 - val_loss: 7.6879e-04
#
# Epoch 00097: val_loss did not improve
# Epoch 98/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.1369e-04 - val_loss: 7.2254e-04
#
# Epoch 00098: val_loss did not improve
# Epoch 99/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 1.1608e-04 - val_loss: 7.2810e-04
#
# Epoch 00099: val_loss did not improve
# Epoch 100/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 1.1260e-04 - val_loss: 7.3817e-04
#
# Epoch 00100: val_loss did not improve
# Epoch 101/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.1285e-04 - val_loss: 7.2407e-04
#
# Epoch 00101: val_loss did not improve
# Epoch 102/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.1252e-04 - val_loss: 7.8923e-04
#
# Epoch 00102: val_loss did not improve
# Epoch 103/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.1129e-04 - val_loss: 7.4565e-04
#
# Epoch 00103: val_loss did not improve
# Epoch 104/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.0928e-04 - val_loss: 7.2508e-04
#
# Epoch 00104: val_loss did not improve
# Epoch 105/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 1.0676e-04 - val_loss: 7.3077e-04
#
# Epoch 00105: val_loss did not improve
# Epoch 106/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.1218e-04 - val_loss: 7.2151e-04
#
# Epoch 00106: val_loss did not improve
# Epoch 107/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.0760e-04 - val_loss: 7.3488e-04
#
# Epoch 00107: val_loss did not improve
# Epoch 108/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.0844e-04 - val_loss: 7.3515e-04
#
# Epoch 00108: val_loss did not improve
# Epoch 109/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.1006e-04 - val_loss: 7.1653e-04
#
# Epoch 00109: val_loss did not improve
# Epoch 110/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.0641e-04 - val_loss: 7.1955e-04
#
# Epoch 00110: val_loss did not improve
# Epoch 111/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.0295e-04 - val_loss: 7.4866e-04
#
# Epoch 00111: val_loss did not improve
# Epoch 112/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.0583e-04 - val_loss: 7.4234e-04
#
# Epoch 00112: val_loss did not improve
# Epoch 113/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.0192e-04 - val_loss: 7.4519e-04
#
# Epoch 00113: val_loss did not improve
# Epoch 114/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.0175e-04 - val_loss: 7.3561e-04
#
# Epoch 00114: val_loss did not improve
# Epoch 115/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.0015e-04 - val_loss: 7.5200e-04
#
# Epoch 00115: val_loss did not improve
# Epoch 116/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 9.9168e-05 - val_loss: 7.2928e-04
#
# Epoch 00116: val_loss did not improve
# Epoch 117/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 9.9681e-05 - val_loss: 7.2784e-04
#
# Epoch 00117: val_loss did not improve
# Epoch 118/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.0027e-04 - val_loss: 7.3724e-04
#
# Epoch 00118: val_loss did not improve
# Epoch 119/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 9.7674e-05 - val_loss: 7.6331e-04
#
# Epoch 00119: val_loss did not improve
# Epoch 120/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 9.8913e-05 - val_loss: 7.3621e-04
#
# Epoch 00120: val_loss did not improve
# Epoch 121/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.0021e-04 - val_loss: 7.3793e-04
#
# Epoch 00121: val_loss did not improve
# Epoch 122/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 1.0143e-04 - val_loss: 7.2830e-04
#
# Epoch 00122: val_loss did not improve
# Epoch 123/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.0112e-04 - val_loss: 7.5729e-04
#
# Epoch 00123: val_loss did not improve
# Epoch 124/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 9.7138e-05 - val_loss: 7.4491e-04
#
# Epoch 00124: val_loss did not improve
# Epoch 125/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 9.3661e-05 - val_loss: 7.5454e-04
#
# Epoch 00125: val_loss did not improve
# Epoch 126/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 9.2810e-05 - val_loss: 7.0487e-04
#
# Epoch 00126: val_loss did not improve
# Epoch 127/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 9.6336e-05 - val_loss: 7.2621e-04
#
# Epoch 00127: val_loss did not improve
# Epoch 128/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 9.7015e-05 - val_loss: 7.2927e-04
#
# Epoch 00128: val_loss did not improve
# Epoch 129/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 9.5540e-05 - val_loss: 7.3415e-04
#
# Epoch 00129: val_loss did not improve
# Epoch 130/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 9.1937e-05 - val_loss: 7.3210e-04
#
# Epoch 00130: val_loss did not improve
# Epoch 131/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 9.0230e-05 - val_loss: 7.5131e-04
#
# Epoch 00131: val_loss did not improve
# Epoch 132/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 9.0508e-05 - val_loss: 7.2617e-04
#
# Epoch 00132: val_loss did not improve
# Epoch 133/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 8.9807e-05 - val_loss: 7.4543e-04
#
# Epoch 00133: val_loss did not improve
# Epoch 134/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 8.9007e-05 - val_loss: 7.4597e-04
#
# Epoch 00134: val_loss did not improve
# Epoch 135/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 9.0201e-05 - val_loss: 7.2615e-04
#
# Epoch 00135: val_loss did not improve
# Epoch 136/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 8.7597e-05 - val_loss: 7.0960e-04
#
# Epoch 00136: val_loss did not improve
# Epoch 137/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 8.5916e-05 - val_loss: 7.4783e-04
#
# Epoch 00137: val_loss did not improve
# Epoch 138/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 8.8268e-05 - val_loss: 7.2333e-04
#
# Epoch 00138: val_loss did not improve
# Epoch 139/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 8.6197e-05 - val_loss: 7.5713e-04
#
# Epoch 00139: val_loss did not improve
# Epoch 140/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 8.5752e-05 - val_loss: 7.4458e-04
#
# Epoch 00140: val_loss did not improve
# Epoch 141/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 8.6691e-05 - val_loss: 7.0648e-04
#
# Epoch 00141: val_loss did not improve
# Epoch 142/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 8.5182e-05 - val_loss: 7.2802e-04
#
# Epoch 00142: val_loss did not improve
# Epoch 143/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 8.2515e-05 - val_loss: 7.2785e-04
#
# Epoch 00143: val_loss did not improve
# Epoch 144/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 8.2326e-05 - val_loss: 7.2714e-04
#
# Epoch 00144: val_loss did not improve
# Epoch 145/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 8.5184e-05 - val_loss: 7.1484e-04
#
# Epoch 00145: val_loss did not improve
# Epoch 146/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 8.3947e-05 - val_loss: 7.1666e-04
#
# Epoch 00146: val_loss did not improve
# Epoch 147/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 8.3940e-05 - val_loss: 7.3812e-04
#
# Epoch 00147: val_loss did not improve
# Epoch 148/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 8.2838e-05 - val_loss: 7.2659e-04
#
# Epoch 00148: val_loss did not improve
# Epoch 149/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 7.9251e-05 - val_loss: 7.2417e-04
#
# Epoch 00149: val_loss did not improve
# Epoch 150/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 8.4998e-05 - val_loss: 7.6014e-04
#
# Epoch 00150: val_loss did not improve

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'data/test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 1s 332us/step - loss: 0.0042 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00193, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00193 to 0.00188, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00188 to 0.00180, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 8.8583e-04 - val_loss: 0.0015
#
# Epoch 00004: val_loss improved from 0.00180 to 0.00154, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 226us/step - loss: 6.6769e-04 - val_loss: 0.0012
#
# Epoch 00005: val_loss improved from 0.00154 to 0.00117, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 5.3730e-04 - val_loss: 0.0010
#
# Epoch 00006: val_loss improved from 0.00117 to 0.00100, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 4.7890e-04 - val_loss: 9.6204e-04
#
# Epoch 00007: val_loss improved from 0.00100 to 0.00096, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 4.4425e-04 - val_loss: 8.6422e-04
#
# Epoch 00008: val_loss improved from 0.00096 to 0.00086, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 3.9525e-04 - val_loss: 8.2162e-04
#
# Epoch 00009: val_loss improved from 0.00086 to 0.00082, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 3.6752e-04 - val_loss: 8.1115e-04
#
# Epoch 00010: val_loss improved from 0.00082 to 0.00081, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 3.4726e-04 - val_loss: 7.8547e-04
#
# Epoch 00011: val_loss improved from 0.00081 to 0.00079, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 3.2671e-04 - val_loss: 7.7709e-04
#
# Epoch 00012: val_loss improved from 0.00079 to 0.00078, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 3.1139e-04 - val_loss: 7.5875e-04
#
# Epoch 00013: val_loss improved from 0.00078 to 0.00076, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 3.0191e-04 - val_loss: 7.8914e-04
#
# Epoch 00014: val_loss did not improve
# Epoch 15/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 2.8703e-04 - val_loss: 7.3309e-04
#
# Epoch 00015: val_loss improved from 0.00076 to 0.00073, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 2.8444e-04 - val_loss: 7.2733e-04
#
# Epoch 00016: val_loss improved from 0.00073 to 0.00073, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 2.6702e-04 - val_loss: 7.0187e-04
#
# Epoch 00017: val_loss improved from 0.00073 to 0.00070, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 2.6269e-04 - val_loss: 7.3979e-04
#
# Epoch 00018: val_loss did not improve
# Epoch 19/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 2.4989e-04 - val_loss: 7.3373e-04
#
# Epoch 00019: val_loss did not improve
# Epoch 20/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 2.4225e-04 - val_loss: 7.2177e-04
#
# Epoch 00020: val_loss did not improve
# Epoch 21/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 2.3542e-04 - val_loss: 6.8298e-04
#
# Epoch 00021: val_loss improved from 0.00070 to 0.00068, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 1s 216us/step - loss: 2.2854e-04 - val_loss: 6.8174e-04
#
# Epoch 00022: val_loss improved from 0.00068 to 0.00068, saving model to best_weights_augment.h5
# Epoch 23/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 2.2179e-04 - val_loss: 6.9003e-04
#
# Epoch 00023: val_loss did not improve
# Epoch 24/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 2.1873e-04 - val_loss: 6.6365e-04
#
# Epoch 00024: val_loss improved from 0.00068 to 0.00066, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 1s 227us/step - loss: 2.1320e-04 - val_loss: 6.4689e-04
#
# Epoch 00025: val_loss improved from 0.00066 to 0.00065, saving model to best_weights_augment.h5
# Epoch 26/150
# 3424/3424 [==============================] - 1s 225us/step - loss: 2.0757e-04 - val_loss: 6.5367e-04
#
# Epoch 00026: val_loss did not improve
# Epoch 27/150
# 3424/3424 [==============================] - 1s 216us/step - loss: 2.0666e-04 - val_loss: 6.6096e-04
#
# Epoch 00027: val_loss did not improve
# Epoch 28/150
# 3424/3424 [==============================] - 1s 216us/step - loss: 2.0714e-04 - val_loss: 6.8157e-04
#
# Epoch 00028: val_loss did not improve
# Epoch 29/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.9572e-04 - val_loss: 6.6801e-04
#
# Epoch 00029: val_loss did not improve
# Epoch 30/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.9101e-04 - val_loss: 6.3652e-04
#
# Epoch 00030: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 31/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.8841e-04 - val_loss: 6.4528e-04
#
# Epoch 00031: val_loss did not improve
# Epoch 32/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.8269e-04 - val_loss: 6.4516e-04
#
# Epoch 00032: val_loss did not improve
# Epoch 33/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.7961e-04 - val_loss: 6.9987e-04
#
# Epoch 00033: val_loss did not improve
# Epoch 34/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.7804e-04 - val_loss: 6.4116e-04
#
# Epoch 00034: val_loss did not improve
# Epoch 35/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 1.7486e-04 - val_loss: 6.7539e-04
#
# Epoch 00035: val_loss did not improve
# Epoch 36/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.7240e-04 - val_loss: 6.1974e-04
#
# Epoch 00036: val_loss improved from 0.00064 to 0.00062, saving model to best_weights_augment.h5
# Epoch 37/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.6853e-04 - val_loss: 6.3303e-04
#
# Epoch 00037: val_loss did not improve
# Epoch 38/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.6470e-04 - val_loss: 6.6976e-04
#
# Epoch 00038: val_loss did not improve
# Epoch 39/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.6906e-04 - val_loss: 6.3979e-04
#
# Epoch 00039: val_loss did not improve
# Epoch 40/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 1.6480e-04 - val_loss: 6.3681e-04
#
# Epoch 00040: val_loss did not improve
# Epoch 41/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 1.6051e-04 - val_loss: 6.6291e-04
#
# Epoch 00041: val_loss did not improve
# Epoch 42/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 1.5978e-04 - val_loss: 6.3416e-04
#
# Epoch 00042: val_loss did not improve
# Epoch 43/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 1.5559e-04 - val_loss: 6.3749e-04
#
# Epoch 00043: val_loss did not improve
# Epoch 44/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 1.5239e-04 - val_loss: 6.3328e-04
#
# Epoch 00044: val_loss did not improve
# Epoch 45/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.5128e-04 - val_loss: 6.4634e-04
#
# Epoch 00045: val_loss did not improve
# Epoch 46/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 1.4848e-04 - val_loss: 6.2005e-04
#
# Epoch 00046: val_loss did not improve
# Epoch 47/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 1.4696e-04 - val_loss: 6.5198e-04
#
# Epoch 00047: val_loss did not improve
# Epoch 48/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 1.4543e-04 - val_loss: 6.4514e-04
#
# Epoch 00048: val_loss did not improve
# Epoch 49/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 1.4467e-04 - val_loss: 6.4723e-04
#
# Epoch 00049: val_loss did not improve
# Epoch 50/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 1.4442e-04 - val_loss: 6.3577e-04
#
# Epoch 00050: val_loss did not improve
# Epoch 51/150
# 3424/3424 [==============================] - 1s 216us/step - loss: 1.4201e-04 - val_loss: 6.5018e-04
#
# Epoch 00051: val_loss did not improve
# Epoch 52/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 1.3813e-04 - val_loss: 6.3573e-04
#
# Epoch 00052: val_loss did not improve
# Epoch 53/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.3567e-04 - val_loss: 6.2890e-04
#
# Epoch 00053: val_loss did not improve
# Epoch 54/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.3235e-04 - val_loss: 6.5024e-04
#
# Epoch 00054: val_loss did not improve
# Epoch 55/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 1.3251e-04 - val_loss: 6.4038e-04
#
# Epoch 00055: val_loss did not improve
# Epoch 56/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.2838e-04 - val_loss: 6.1947e-04
#
# Epoch 00056: val_loss improved from 0.00062 to 0.00062, saving model to best_weights_augment.h5
# Epoch 57/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.2815e-04 - val_loss: 6.6698e-04
#
# Epoch 00057: val_loss did not improve
# Epoch 58/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.2769e-04 - val_loss: 6.3864e-04
#
# Epoch 00058: val_loss did not improve
# Epoch 59/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.2656e-04 - val_loss: 6.3973e-04
#
# Epoch 00059: val_loss did not improve
# Epoch 60/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.2251e-04 - val_loss: 6.5275e-04
#
# Epoch 00060: val_loss did not improve
# Epoch 61/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.2349e-04 - val_loss: 6.3034e-04
#
# Epoch 00061: val_loss did not improve
# Epoch 62/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.1898e-04 - val_loss: 6.4024e-04
#
# Epoch 00062: val_loss did not improve
# Epoch 63/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 1.2118e-04 - val_loss: 6.3559e-04
#
# Epoch 00063: val_loss did not improve
# Epoch 64/150
# 3424/3424 [==============================] - 1s 216us/step - loss: 1.1887e-04 - val_loss: 6.1474e-04
#
# Epoch 00064: val_loss improved from 0.00062 to 0.00061, saving model to best_weights_augment.h5
# Epoch 65/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 1.1810e-04 - val_loss: 6.4234e-04
#
# Epoch 00065: val_loss did not improve
# Epoch 66/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 1.1867e-04 - val_loss: 6.1747e-04
#
# Epoch 00066: val_loss did not improve
# Epoch 67/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 1.1517e-04 - val_loss: 6.1867e-04
#
# Epoch 00067: val_loss did not improve
# Epoch 68/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.1291e-04 - val_loss: 6.2184e-04
#
# Epoch 00068: val_loss did not improve
# Epoch 69/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.1445e-04 - val_loss: 6.3815e-04
#
# Epoch 00069: val_loss did not improve
# Epoch 70/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.1370e-04 - val_loss: 6.2361e-04
#
# Epoch 00070: val_loss did not improve
# Epoch 71/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.1096e-04 - val_loss: 6.3417e-04
#
# Epoch 00071: val_loss did not improve
# Epoch 72/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.0875e-04 - val_loss: 6.2268e-04
#
# Epoch 00072: val_loss did not improve
# Epoch 73/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 1.0799e-04 - val_loss: 6.2153e-04
#
# Epoch 00073: val_loss did not improve
# Epoch 74/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.0847e-04 - val_loss: 6.1133e-04
#
# Epoch 00074: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5
# Epoch 75/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.0699e-04 - val_loss: 6.3126e-04
#
# Epoch 00075: val_loss did not improve
# Epoch 76/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.0543e-04 - val_loss: 6.2940e-04
#
# Epoch 00076: val_loss did not improve
# Epoch 77/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.0318e-04 - val_loss: 6.1984e-04
#
# Epoch 00077: val_loss did not improve
# Epoch 78/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.0411e-04 - val_loss: 6.3173e-04
#
# Epoch 00078: val_loss did not improve
# Epoch 79/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.0172e-04 - val_loss: 6.3042e-04
#
# Epoch 00079: val_loss did not improve
# Epoch 80/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.0265e-04 - val_loss: 6.0661e-04
#
# Epoch 00080: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5
# Epoch 81/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 1.0100e-04 - val_loss: 6.4416e-04
#
# Epoch 00081: val_loss did not improve
# Epoch 82/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.0134e-04 - val_loss: 6.1707e-04
#
# Epoch 00082: val_loss did not improve
# Epoch 83/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.0072e-04 - val_loss: 6.1590e-04
#
# Epoch 00083: val_loss did not improve
# Epoch 84/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.0098e-04 - val_loss: 6.3200e-04
#
# Epoch 00084: val_loss did not improve
# Epoch 85/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.0118e-04 - val_loss: 6.3622e-04
#
# Epoch 00085: val_loss did not improve
# Epoch 86/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 9.8546e-05 - val_loss: 6.1652e-04
#
# Epoch 00086: val_loss did not improve
# Epoch 87/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 9.9509e-05 - val_loss: 6.2601e-04
#
# Epoch 00087: val_loss did not improve
# Epoch 88/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 9.6595e-05 - val_loss: 6.3112e-04
#
# Epoch 00088: val_loss did not improve
# Epoch 89/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 9.7163e-05 - val_loss: 6.1302e-04
#
# Epoch 00089: val_loss did not improve
# Epoch 90/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 9.8336e-05 - val_loss: 6.3311e-04
#
# Epoch 00090: val_loss did not improve
# Epoch 91/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 9.4594e-05 - val_loss: 6.1845e-04
#
# Epoch 00091: val_loss did not improve
# Epoch 92/150
# 3424/3424 [==============================] - 1s 216us/step - loss: 9.4106e-05 - val_loss: 6.1891e-04
#
# Epoch 00092: val_loss did not improve
# Epoch 93/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 9.2531e-05 - val_loss: 6.2780e-04
#
# Epoch 00093: val_loss did not improve
# Epoch 94/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 9.4398e-05 - val_loss: 6.1335e-04
#
# Epoch 00094: val_loss did not improve
# Epoch 95/150
# 3424/3424 [==============================] - 1s 224us/step - loss: 9.4790e-05 - val_loss: 6.1449e-04
#
# Epoch 00095: val_loss did not improve
# Epoch 96/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 9.1538e-05 - val_loss: 6.3705e-04
#
# Epoch 00096: val_loss did not improve
# Epoch 97/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 9.2769e-05 - val_loss: 6.2668e-04
#
# Epoch 00097: val_loss did not improve
# Epoch 98/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 9.3014e-05 - val_loss: 6.1520e-04
#
# Epoch 00098: val_loss did not improve
# Epoch 99/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 9.0194e-05 - val_loss: 6.2816e-04
#
# Epoch 00099: val_loss did not improve
# Epoch 100/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 8.9894e-05 - val_loss: 6.2441e-04
#
# Epoch 00100: val_loss did not improve
# Epoch 101/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 8.9215e-05 - val_loss: 6.2711e-04
#
# Epoch 00101: val_loss did not improve
# Epoch 102/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 9.0593e-05 - val_loss: 6.4163e-04
#
# Epoch 00102: val_loss did not improve
# Epoch 103/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 9.0805e-05 - val_loss: 6.2796e-04
#
# Epoch 00103: val_loss did not improve
# Epoch 104/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 8.9334e-05 - val_loss: 6.1687e-04
#
# Epoch 00104: val_loss did not improve
# Epoch 105/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 9.0781e-05 - val_loss: 6.1608e-04
#
# Epoch 00105: val_loss did not improve
# Epoch 106/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 9.1079e-05 - val_loss: 6.0672e-04
#
# Epoch 00106: val_loss did not improve
# Epoch 107/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 9.0492e-05 - val_loss: 6.3439e-04
#
# Epoch 00107: val_loss did not improve
# Epoch 108/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 8.9637e-05 - val_loss: 6.4256e-04
#
# Epoch 00108: val_loss did not improve
# Epoch 109/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 8.8130e-05 - val_loss: 6.1123e-04
#
# Epoch 00109: val_loss did not improve
# Epoch 110/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 8.7038e-05 - val_loss: 6.1739e-04
#
# Epoch 00110: val_loss did not improve
# Epoch 111/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 8.5128e-05 - val_loss: 6.2526e-04
#
# Epoch 00111: val_loss did not improve
# Epoch 112/150
# 3424/3424 [==============================] - 1s 228us/step - loss: 8.6224e-05 - val_loss: 6.2376e-04
#
# Epoch 00112: val_loss did not improve
# Epoch 113/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 8.6901e-05 - val_loss: 6.2763e-04
#
# Epoch 00113: val_loss did not improve
# Epoch 114/150
# 3424/3424 [==============================] - 1s 216us/step - loss: 8.7267e-05 - val_loss: 6.1174e-04
#
# Epoch 00114: val_loss did not improve
# Epoch 115/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 8.7821e-05 - val_loss: 6.3487e-04
#
# Epoch 00115: val_loss did not improve
# Epoch 116/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 8.5961e-05 - val_loss: 6.1210e-04
#
# Epoch 00116: val_loss did not improve
# Epoch 117/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 8.2851e-05 - val_loss: 6.2011e-04
#
# Epoch 00117: val_loss did not improve
# Epoch 118/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 8.5980e-05 - val_loss: 6.3532e-04
#
# Epoch 00118: val_loss did not improve
# Epoch 119/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 8.4874e-05 - val_loss: 6.0098e-04
#
# Epoch 00119: val_loss improved from 0.00061 to 0.00060, saving model to best_weights_augment.h5
# Epoch 120/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 8.3084e-05 - val_loss: 6.1929e-04
#
# Epoch 00120: val_loss did not improve
# Epoch 121/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 8.3811e-05 - val_loss: 6.2065e-04
#
# Epoch 00121: val_loss did not improve
# Epoch 122/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 8.1512e-05 - val_loss: 6.1626e-04
#
# Epoch 00122: val_loss did not improve
# Epoch 123/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 8.1146e-05 - val_loss: 6.3552e-04
#
# Epoch 00123: val_loss did not improve
# Epoch 124/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 8.6999e-05 - val_loss: 6.4671e-04
#
# Epoch 00124: val_loss did not improve
# Epoch 125/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 8.5155e-05 - val_loss: 6.1297e-04
#
# Epoch 00125: val_loss did not improve
# Epoch 126/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 8.4174e-05 - val_loss: 6.2267e-04
#
# Epoch 00126: val_loss did not improve
# Epoch 127/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 8.2492e-05 - val_loss: 6.1970e-04
#
# Epoch 00127: val_loss did not improve
# Epoch 128/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 8.2957e-05 - val_loss: 6.1703e-04
#
# Epoch 00128: val_loss did not improve
# Epoch 129/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 8.4494e-05 - val_loss: 6.2258e-04
#
# Epoch 00129: val_loss did not improve
# Epoch 130/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 7.9117e-05 - val_loss: 6.0194e-04
#
# Epoch 00130: val_loss did not improve
# Epoch 131/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 8.0617e-05 - val_loss: 6.1320e-04
#
# Epoch 00131: val_loss did not improve
# Epoch 132/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 8.0642e-05 - val_loss: 6.0083e-04
#
# Epoch 00132: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 133/150
# 3424/3424 [==============================] - 1s 226us/step - loss: 8.1360e-05 - val_loss: 6.0934e-04
#
# Epoch 00133: val_loss did not improve
# Epoch 134/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 8.1505e-05 - val_loss: 6.1563e-04
#
# Epoch 00134: val_loss did not improve
# Epoch 135/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 8.0810e-05 - val_loss: 6.2194e-04
#
# Epoch 00135: val_loss did not improve
# Epoch 136/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 7.8294e-05 - val_loss: 6.1758e-04
#
# Epoch 00136: val_loss did not improve
# Epoch 137/150
# 3424/3424 [==============================] - 1s 216us/step - loss: 7.8725e-05 - val_loss: 6.4536e-04
#
# Epoch 00137: val_loss did not improve
# Epoch 138/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 8.1068e-05 - val_loss: 6.2084e-04
#
# Epoch 00138: val_loss did not improve
# Epoch 139/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 8.3653e-05 - val_loss: 6.3321e-04
#
# Epoch 00139: val_loss did not improve
# Epoch 140/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 7.9735e-05 - val_loss: 6.0740e-04
#
# Epoch 00140: val_loss did not improve
# Epoch 141/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 7.8969e-05 - val_loss: 6.3459e-04
#
# Epoch 00141: val_loss did not improve
# Epoch 142/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 8.0212e-05 - val_loss: 6.1091e-04
#
# Epoch 00142: val_loss did not improve
# Epoch 143/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 8.0899e-05 - val_loss: 6.2190e-04
#
# Epoch 00143: val_loss did not improve
# Epoch 144/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 7.8704e-05 - val_loss: 6.2321e-04
#
# Epoch 00144: val_loss did not improve
# Epoch 145/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 7.8215e-05 - val_loss: 6.1294e-04
#
# Epoch 00145: val_loss did not improve
# Epoch 146/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 7.5893e-05 - val_loss: 6.3684e-04
#
# Epoch 00146: val_loss did not improve
# Epoch 147/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 7.6794e-05 - val_loss: 6.1878e-04
#
# Epoch 00147: val_loss did not improve
# Epoch 148/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 7.9793e-05 - val_loss: 6.2377e-04
#
# Epoch 00148: val_loss did not improve
# Epoch 149/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 7.8154e-05 - val_loss: 6.4038e-04
#
# Epoch 00149: val_loss did not improve
# Epoch 150/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 7.7872e-05 - val_loss: 6.0928e-04
#
# Epoch 00150: val_loss did not improve

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
